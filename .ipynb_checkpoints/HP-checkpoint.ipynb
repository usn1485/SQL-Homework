# %%
from sqlalchemy import create_engine
import psycopg2
from databaseconfig import hp_pwd
import pandas as pd
import matplotlib.pyplot as plt

# %%
engine = create_engine(f'postgresql+psycopg2://postgres:{hp_pwd}@localhost/HP_DB')

# %%
connection = engine.connect()

# %%
#Query the records in the database 
data=pd.read_sql('select * from avg_salarybyemp_title;',connection)

# %%
#df=pd.DataFrame(data)
#df

# %%
AvgSalaryBar=data.plot.bar(y='avg salary',x="title", title = "Avg salary of employees by Title ",
                                 width = 0.75,figsize = (10,8),rot = 30,alpha = 0.75,colormap="plasma")

AvgSalaryBar.set_xlabel("Title")
AvgSalaryBar.set_ylabel("Avg Salary")
plt.savefig("Avg_salary_of_employees_by_Title.png")
plt.show()
